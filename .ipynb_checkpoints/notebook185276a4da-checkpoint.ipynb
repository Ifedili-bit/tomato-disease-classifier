JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/test/Tomato___healthy/image (1342).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/test/Tomato___healthy/image (1097).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/test/Tomato___healthy/image (1113).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/test/Tomato___healthy/image (164).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/test/Tomato___healthy/image (1044).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/test/Tomato___healthy/image (768).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/test/Tomato___healthy/image (1181).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/test/Tomato___healthy/image (1125).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/test/Tomato___healthy/image (532).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/test/Tomato___healthy/image (1290).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/test/Tomato___healthy/image (1565).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/test/Tomato___healthy/image (1218).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/test/Tomato___healthy/image (792).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/test/Tomato___healthy/image (381).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/test/Tomato___healthy/image (1406).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/test/Tomato___healthy/image (776).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/test/Tomato___healthy/image (1429).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/test/Tomato___healthy/image (245).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/test/Tomato___healthy/image (1403).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/test/Tomato___healthy/image (1404).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/test/Tomato___healthy/image (115).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/test/Tomato___healthy/image (727).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/test/Tomato___healthy/image (571).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/test/Tomato___healthy/image (233).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/test/Tomato___healthy/image (1353).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/test/Tomato___healthy/image (1297).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/test/Tomato___healthy/image (1329).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/test/Tomato___healthy/image (1271).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/test/Tomato___healthy/image (1266).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/test/Tomato___healthy/image (875).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/test/Tomato___healthy/image (1530).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/test/Tomato___healthy/image (69).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/test/Tomato___healthy/image (886).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/test/Tomato___healthy/image (1211).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/test/Tomato___healthy/image (1308).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/test/Tomato___healthy/image (1109).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/test/Tomato___healthy/image (1060).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/test/Tomato___healthy/image (1363).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/test/Tomato___healthy/image (939).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/test/Tomato___healthy/image (722).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/test/Tomato___healthy/image (511).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/test/Tomato___healthy/image (775).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/test/Tomato___healthy/image (396).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/test/Tomato___healthy/image (339).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/test/Tomato___healthy/image (1549).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/test/Tomato___healthy/image (541).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/test/Tomato___healthy/image (941).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/test/Tomato___healthy/image (845).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/test/Tomato___healthy/image (1242).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/test/Tomato___healthy/image (1246).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/test/Tomato___healthy/image (1195).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/test/Tomato___healthy/image (270).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/test/Tomato___healthy/image (68).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/test/Tomato___healthy/image (703).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/test/Tomato___healthy/image (21).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/test/Tomato___healthy/image (1488).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/test/Tomato___healthy/image (237).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/test/Tomato___healthy/image (1220).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/test/Tomato___healthy/image (911).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/test/Tomato___healthy/image (1502).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/test/Tomato___healthy/image (902).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/test/Tomato___healthy/image (743).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/test/Tomato___healthy/image (648).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/test/Tomato___healthy/image (498).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/test/Tomato___healthy/image (153).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/test/Tomato___healthy/image (1025).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/test/Tomato___healthy/image (304).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/test/Tomato___healthy/image (1144).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/test/Tomato___healthy/image (599).JPG
# ...
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/train/Tomato___Spider_mites Two-spotted_spider_mite/image (479).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/train/Tomato___Spider_mites Two-spotted_spider_mite/image (1166).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/train/Tomato___Spider_mites Two-spotted_spider_mite/image (1359).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/train/Tomato___Spider_mites Two-spotted_spider_mite/image (1563).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/train/Tomato___Spider_mites Two-spotted_spider_mite/image (185).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/train/Tomato___Spider_mites Two-spotted_spider_mite/image (223).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/train/Tomato___Spider_mites Two-spotted_spider_mite/image (1592).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/train/Tomato___Spider_mites Two-spotted_spider_mite/image (1501).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/train/Tomato___Spider_mites Two-spotted_spider_mite/image (1030).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/train/Tomato___Spider_mites Two-spotted_spider_mite/image (1577).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/train/Tomato___Spider_mites Two-spotted_spider_mite/image (20).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/train/Tomato___Spider_mites Two-spotted_spider_mite/image (1586).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/train/Tomato___Spider_mites Two-spotted_spider_mite/image (937).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/train/Tomato___Spider_mites Two-spotted_spider_mite/image (76).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/train/Tomato___Spider_mites Two-spotted_spider_mite/image (186).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/train/Tomato___Spider_mites Two-spotted_spider_mite/image (823).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/train/Tomato___Spider_mites Two-spotted_spider_mite/image (1552).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/train/Tomato___Spider_mites Two-spotted_spider_mite/image (940).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/train/Tomato___Spider_mites Two-spotted_spider_mite/image (1).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/train/Tomato___Spider_mites Two-spotted_spider_mite/image (1536).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/train/Tomato___Spider_mites Two-spotted_spider_mite/image (1358).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/train/Tomato___Spider_mites Two-spotted_spider_mite/image (1262).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/train/Tomato___Spider_mites Two-spotted_spider_mite/image (951).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/train/Tomato___Spider_mites Two-spotted_spider_mite/image (544).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/train/Tomato___Spider_mites Two-spotted_spider_mite/image (1215).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/train/Tomato___Spider_mites Two-spotted_spider_mite/image (1651).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/train/Tomato___Spider_mites Two-spotted_spider_mite/image (1021).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/train/Tomato___Spider_mites Two-spotted_spider_mite/image (668).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/train/Tomato___Spider_mites Two-spotted_spider_mite/image (1005).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/train/Tomato___Spider_mites Two-spotted_spider_mite/image (330).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/train/Tomato___Spider_mites Two-spotted_spider_mite/image (710).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/train/Tomato___Spider_mites Two-spotted_spider_mite/image (1534).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/train/Tomato___Spider_mites Two-spotted_spider_mite/image (1493).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/train/Tomato___Spider_mites Two-spotted_spider_mite/image (1550).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/train/Tomato___Spider_mites Two-spotted_spider_mite/image (844).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/train/Tomato___Spider_mites Two-spotted_spider_mite/image (1667).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/train/Tomato___Spider_mites Two-spotted_spider_mite/image (3).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/train/Tomato___Spider_mites Two-spotted_spider_mite/image (676).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/train/Tomato___Spider_mites Two-spotted_spider_mite/image (759).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/train/Tomato___Spider_mites Two-spotted_spider_mite/image (494).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/train/Tomato___Spider_mites Two-spotted_spider_mite/image (1169).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/train/Tomato___Spider_mites Two-spotted_spider_mite/image (1300).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/train/Tomato___Spider_mites Two-spotted_spider_mite/image (1143).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/train/Tomato___Spider_mites Two-spotted_spider_mite/image (1516).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/train/Tomato___Spider_mites Two-spotted_spider_mite/image (324).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/train/Tomato___Spider_mites Two-spotted_spider_mite/image (578).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/train/Tomato___Spider_mites Two-spotted_spider_mite/image (559).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/train/Tomato___Spider_mites Two-spotted_spider_mite/image (167).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/train/Tomato___Spider_mites Two-spotted_spider_mite/image (628).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/train/Tomato___Spider_mites Two-spotted_spider_mite/image (87).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/train/Tomato___Spider_mites Two-spotted_spider_mite/image (1593).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/train/Tomato___Spider_mites Two-spotted_spider_mite/image (201).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/train/Tomato___Spider_mites Two-spotted_spider_mite/image (885).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/train/Tomato___Spider_mites Two-spotted_spider_mite/image (1420).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/train/Tomato___Spider_mites Two-spotted_spider_mite/image (82).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/train/Tomato___Spider_mites Two-spotted_spider_mite/image (679).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/train/Tomato___Spider_mites Two-spotted_spider_mite/image (415).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/train/Tomato___Spider_mites Two-spotted_spider_mite/image (1356).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/train/Tomato___Spider_mites Two-spotted_spider_mite/image (905).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/train/Tomato___Spider_mites Two-spotted_spider_mite/image (380).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/train/Tomato___Spider_mites Two-spotted_spider_mite/image (991).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/train/Tomato___Spider_mites Two-spotted_spider_mite/image (592).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/train/Tomato___Spider_mites Two-spotted_spider_mite/image (1615).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/train/Tomato___Spider_mites Two-spotted_spider_mite/image (856).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/train/Tomato___Spider_mites Two-spotted_spider_mite/image (1275).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/train/Tomato___Spider_mites Two-spotted_spider_mite/image (740).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/train/Tomato___Spider_mites Two-spotted_spider_mite/image (313).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/train/Tomato___Spider_mites Two-spotted_spider_mite/image (307).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/train/Tomato___Spider_mites Two-spotted_spider_mite/image (854).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/train/Tomato___Spider_mites Two-spotted_spider_mite/image (1595).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/train/Tomato___Spider_mites Two-spotted_spider_mite/image (1012).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/train/Tomato___Spider_mites Two-spotted_spider_mite/image (189).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/train/Tomato___Spider_mites Two-spotted_spider_mite/image (1602).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/train/Tomato___Spider_mites Two-spotted_spider_mite/image (352).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/train/Tomato___Spider_mites Two-spotted_spider_mite/image (372).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/train/Tomato___Spider_mites Two-spotted_spider_mite/image (872).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/train/Tomato___Spider_mites Two-spotted_spider_mite/image (490).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/train/Tomato___Spider_mites Two-spotted_spider_mite/image (336).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/train/Tomato___Spider_mites Two-spotted_spider_mite/image (607).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/train/Tomato___Spider_mites Two-spotted_spider_mite/image (1361).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/train/Tomato___Spider_mites Two-spotted_spider_mite/image (1338).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/train/Tomato___Spider_mites Two-spotted_spider_mite/image (468).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/train/Tomato___Spider_mites Two-spotted_spider_mite/image (569).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/train/Tomato___Spider_mites Two-spotted_spider_mite/image (1675).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/train/Tomato___Spider_mites Two-spotted_spider_mite/image (1212).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/train/Tomato___Spider_mites Two-spotted_spider_mite/image (1140).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/train/Tomato___Spider_mites Two-spotted_spider_mite/image (634).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/train/Tomato___Spider_mites Two-spotted_spider_mite/image (551).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/train/Tomato___Spider_mites Two-spotted_spider_mite/image (1430).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/train/Tomato___Spider_mites Two-spotted_spider_mite/image (10).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/train/Tomato___Spider_mites Two-spotted_spider_mite/image (1204).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/train/Tomato___Spider_mites Two-spotted_spider_mite/image (769).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/train/Tomato___Spider_mites Two-spotted_spider_mite/image (1580).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/train/Tomato___Spider_mites Two-spotted_spider_mite/image (1547).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/train/Tomato___Spider_mites Two-spotted_spider_mite/image (432).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/train/Tomato___Spider_mites Two-spotted_spider_mite/image (137).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/train/Tomato___Spider_mites Two-spotted_spider_mite/image (491).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/train/Tomato___Spider_mites Two-spotted_spider_mite/image (1317).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/train/Tomato___Spider_mites Two-spotted_spider_mite/image (520).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/train/Tomato___Spider_mites Two-spotted_spider_mite/image (639).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/train/Tomato___Spider_mites Two-spotted_spider_mite/image (398).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/train/Tomato___Spider_mites Two-spotted_spider_mite/image (1254).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/train/Tomato___Spider_mites Two-spotted_spider_mite/image (1408).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/train/Tomato___Spider_mites Two-spotted_spider_mite/image (1491).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/train/Tomato___Spider_mites Two-spotted_spider_mite/image (1360).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/train/Tomato___Spider_mites Two-spotted_spider_mite/image (128).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/train/Tomato___Spider_mites Two-spotted_spider_mite/image (1641).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/train/Tomato___Spider_mites Two-spotted_spider_mite/image (1346).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/train/Tomato___Spider_mites Two-spotted_spider_mite/image (214).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/train/Tomato___Spider_mites Two-spotted_spider_mite/image (1526).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/train/Tomato___Spider_mites Two-spotted_spider_mite/image (1345).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/train/Tomato___Spider_mites Two-spotted_spider_mite/image (1512).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/train/Tomato___Spider_mites Two-spotted_spider_mite/image (1070).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/train/Tomato___Spider_mites Two-spotted_spider_mite/image (1504).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/train/Tomato___Spider_mites Two-spotted_spider_mite/image (565).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/train/Tomato___Spider_mites Two-spotted_spider_mite/image (172).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/train/Tomato___Spider_mites Two-spotted_spider_mite/image (1013).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/train/Tomato___Spider_mites Two-spotted_spider_mite/image (930).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/train/Tomato___Spider_mites Two-spotted_spider_mite/image (394).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/train/Tomato___Spider_mites Two-spotted_spider_mite/image (1531).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/train/Tomato___Spider_mites Two-spotted_spider_mite/image (44).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/train/Tomato___Spider_mites Two-spotted_spider_mite/image (448).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/train/Tomato___Spider_mites Two-spotted_spider_mite/image (1546).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/train/Tomato___Spider_mites Two-spotted_spider_mite/image (449).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/train/Tomato___Spider_mites Two-spotted_spider_mite/image (322).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/train/Tomato___Spider_mites Two-spotted_spider_mite/image (835).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/train/Tomato___Spider_mites Two-spotted_spider_mite/image (830).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/train/Tomato___Spider_mites Two-spotted_spider_mite/image (536).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/train/Tomato___Spider_mites Two-spotted_spider_mite/image (609).JPG
# /kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/train/Tomato___Spider_mites Two-spotted_spider_mite/image (63).JPG

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.preprocessing import image_dataset_from_directory

# Paths
train_dir = "/kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/train"
test_dir  = "/kaggle/input/tomato-leaf-disease/Tomato Leaf Disease/test"
# Out:
# 2025-09-17 10:11:26.468656: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1758103886.645434      36 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1758103886.695561      36 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
# Data augmentation
data_augmentation = keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.2),
    layers.RandomZoom(0.2),
    layers.RandomContrast(0.2),
])

# Load training & test sets
img_size = (224, 224)
batch_size = 32

train_data = image_dataset_from_directory(
    train_dir,
    image_size=img_size,
    batch_size=batch_size,
    shuffle=True
)

test_data = image_dataset_from_directory(
    test_dir,
    image_size=img_size,
    batch_size=batch_size
)

# Save class names
class_names = train_data.class_names
print("Class names:", class_names)

# Prefetch for speed
train_data = train_data.prefetch(buffer_size=tf.data.AUTOTUNE)
test_data = test_data.prefetch(buffer_size=tf.data.AUTOTUNE)
# Out:
# I0000 00:00:1758103912.926072      36 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13942 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1758103912.926760      36 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13942 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Found 15064 files belonging to 10 classes.
# Found 3771 files belonging to 10 classes.
# Class names: ['Tomato___Bacterial_spot', 'Tomato___Early_blight', 'Tomato___Late_blight', 'Tomato___Leaf_Mold', 'Tomato___Septoria_leaf_spot', 'Tomato___Spider_mites Two-spotted_spider_mite', 'Tomato___Target_Spot', 'Tomato___Tomato_Yellow_Leaf_Curl_Virus', 'Tomato___Tomato_mosaic_virus', 'Tomato___healthy']

# %%
# Load MobileNetV2 with pretrained weights
base_model = MobileNetV2(weights="imagenet", include_top=False, input_shape=(224, 224, 3))

# Freeze most layers, keep last 30 trainable for fine-tuning
base_model.trainable = True
for layer in base_model.layers[:-30]:
    layer.trainable = False

# Build model
inputs = keras.Input(shape=(224, 224, 3))
x = data_augmentation(inputs)
x = keras.applications.mobilenet_v2.preprocess_input(x)
x = base_model(x, training=False)
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dropout(0.3)(x)
outputs = layers.Dense(len(class_names), activation="softmax")(x)

model = keras.Model(inputs, outputs)

# Compile with low LR for fine-tuning
model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=1e-5),
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ sequential (Sequential)         │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ true_divide (TrueDivide)        │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ subtract (Subtract)             │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ mobilenetv2_1.00_224            │ (None, 7, 7, 1280)     │     2,257,984 │
# │ (Functional)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 1280)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 1280)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 10)             │        12,810 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,270,794 (8.66 MB)
#  Trainable params: 1,539,210 (5.87 MB)
#  Non-trainable params: 731,584 (2.79 MB)

# %%
callbacks = [
    keras.callbacks.EarlyStopping(patience=5, restore_best_weights=True),
    keras.callbacks.ModelCheckpoint("best_model.keras", save_best_only=True)
]

history = model.fit(
    train_data,
    validation_data=test_data,
    epochs=25,
    callbacks=callbacks
)
# Out:
# Epoch 1/25
# I0000 00:00:1758104011.617025      98 cuda_dnn.cc:529] Loaded cuDNN version 90300
# 471/471 ━━━━━━━━━━━━━━━━━━━━ 60s 90ms/step - accuracy: 0.3313 - loss: 2.0005 - val_accuracy: 0.5924 - val_loss: 1.2252
# Epoch 2/25
# 471/471 ━━━━━━━━━━━━━━━━━━━━ 42s 89ms/step - accuracy: 0.7361 - loss: 0.8297 - val_accuracy: 0.7346 - val_loss: 0.7959
# Epoch 3/25
# 471/471 ━━━━━━━━━━━━━━━━━━━━ 41s 86ms/step - accuracy: 0.8175 - loss: 0.5784 - val_accuracy: 0.8255 - val_loss: 0.5532
# Epoch 4/25
# 471/471 ━━━━━━━━━━━━━━━━━━━━ 41s 88ms/step - accuracy: 0.8528 - loss: 0.4554 - val_accuracy: 0.8706 - val_loss: 0.4144
# Epoch 5/25
# 471/471 ━━━━━━━━━━━━━━━━━━━━ 41s 88ms/step - accuracy: 0.8784 - loss: 0.3754 - val_accuracy: 0.8921 - val_loss: 0.3441
# Epoch 6/25
# 471/471 ━━━━━━━━━━━━━━━━━━━━ 41s 88ms/step - accuracy: 0.8930 - loss: 0.3289 - val_accuracy: 0.9075 - val_loss: 0.2924
# Epoch 7/25
# 471/471 ━━━━━━━━━━━━━━━━━━━━ 41s 88ms/step - accuracy: 0.9062 - loss: 0.2873 - val_accuracy: 0.9146 - val_loss: 0.2660
# Epoch 8/25
# 471/471 ━━━━━━━━━━━━━━━━━━━━ 41s 87ms/step - accuracy: 0.9189 - loss: 0.2562 - val_accuracy: 0.9223 - val_loss: 0.2412
# Epoch 9/25
# 471/471 ━━━━━━━━━━━━━━━━━━━━ 41s 87ms/step - accuracy: 0.9240 - loss: 0.2339 - val_accuracy: 0.9247 - val_loss: 0.2340
# Epoch 10/25
# 471/471 ━━━━━━━━━━━━━━━━━━━━ 41s 88ms/step - accuracy: 0.9300 - loss: 0.2146 - val_accuracy: 0.9326 - val_loss: 0.2119
# Epoch 11/25
# 471/471 ━━━━━━━━━━━━━━━━━━━━ 41s 88ms/step - accuracy: 0.9351 - loss: 0.1939 - val_accuracy: 0.9321 - val_loss: 0.2098
# Epoch 12/25
# 471/471 ━━━━━━━━━━━━━━━━━━━━ 41s 88ms/step - accuracy: 0.9395 - loss: 0.1825 - val_accuracy: 0.9374 - val_loss: 0.1950
# Epoch 13/25
# 471/471 ━━━━━━━━━━━━━━━━━━━━ 41s 87ms/step - accuracy: 0.9409 - loss: 0.1727 - val_accuracy: 0.9281 - val_loss: 0.2105
# Epoch 14/25
# 471/471 ━━━━━━━━━━━━━━━━━━━━ 41s 87ms/step - accuracy: 0.9427 - loss: 0.1720 - val_accuracy: 0.9361 - val_loss: 0.1980
# Epoch 15/25
# 471/471 ━━━━━━━━━━━━━━━━━━━━ 41s 88ms/step - accuracy: 0.9440 - loss: 0.1655 - val_accuracy: 0.9433 - val_loss: 0.1833
# Epoch 16/25
# 471/471 ━━━━━━━━━━━━━━━━━━━━ 41s 87ms/step - accuracy: 0.9508 - loss: 0.1477 - val_accuracy: 0.9419 - val_loss: 0.1856
# Epoch 17/25
# 471/471 ━━━━━━━━━━━━━━━━━━━━ 42s 88ms/step - accuracy: 0.9538 - loss: 0.1347 - val_accuracy: 0.9451 - val_loss: 0.1766
# Epoch 18/25
# 471/471 ━━━━━━━━━━━━━━━━━━━━ 41s 88ms/step - accuracy: 0.9547 - loss: 0.1365 - val_accuracy: 0.9422 - val_loss: 0.1727
# Epoch 19/25
# 471/471 ━━━━━━━━━━━━━━━━━━━━ 41s 88ms/step - accuracy: 0.9612 - loss: 0.1141 - val_accuracy: 0.9464 - val_loss: 0.1623
# Epoch 20/25
# 471/471 ━━━━━━━━━━━━━━━━━━━━ 41s 86ms/step - accuracy: 0.9604 - loss: 0.1166 - val_accuracy: 0.9462 - val_loss: 0.1665
# Epoch 21/25
# 471/471 ━━━━━━━━━━━━━━━━━━━━ 41s 86ms/step - accuracy: 0.9612 - loss: 0.1165 - val_accuracy: 0.9483 - val_loss: 0.1625
# Epoch 22/25
# 471/471 ━━━━━━━━━━━━━━━━━━━━ 41s 86ms/step - accuracy: 0.9665 - loss: 0.1038 - val_accuracy: 0.9462 - val_loss: 0.1646
# Epoch 23/25
# 471/471 ━━━━━━━━━━━━━━━━━━━━ 41s 88ms/step - accuracy: 0.9654 - loss: 0.1105 - val_accuracy: 0.9523 - val_loss: 0.1503
# Epoch 24/25
# 471/471 ━━━━━━━━━━━━━━━━━━━━ 41s 87ms/step - accuracy: 0.9713 - loss: 0.0899 - val_accuracy: 0.9480 - val_loss: 0.1564
# Epoch 25/25
# 471/471 ━━━━━━━━━━━━━━━━━━━━ 41s 88ms/step - accuracy: 0.9697 - loss: 0.0930 - val_accuracy: 0.9520 - val_loss: 0.1462

# %%
test_loss, test_acc = model.evaluate(test_data)
print("Test Accuracy:", test_acc)
# Out:
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 6s 52ms/step - accuracy: 0.9530 - loss: 0.1421
# Test Accuracy: 0.9520021080970764

# %%
import requests
from PIL import Image

# Example image URL
url = "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQDAr_Ewp3xi3MFHdiXewcuarqV6qKWk1YYdzpQfK4NITH6jZMTW1QIPLJj5AjjYs1DskQ&usqp=CAU"
response = requests.get(url, stream=True)
img = Image.open(response.raw).convert("RGB")

# Preprocess
img = img.resize((224, 224))
img_array = np.array(img) / 255.0
img_array = np.expand_dims(img_array, axis=0)

# Predict
pred = model.predict(img_array)
print("Prediction:", class_names[np.argmax(pred)])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Prediction: Tomato___Late_blight

# %%
# Save the whole model (architecture + weights + optimizer state)
model.save("plant_disease_model.h5")
